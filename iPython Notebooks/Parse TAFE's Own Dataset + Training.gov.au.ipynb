# %% [markdown]
# # In the grand scheme of notebooks, this one comes first.
# ## Purpose of this notebook
# 1. Take the data.sa.gov.au csv file
# 1. Download the SET of distinct URLs from TAFE SA site
# 1. Download the SET of distinct URLs from training.gov.au
# 1. Parse saved training.gov.au HTML files for ASCED narrow FOE data and attach to each course
# 1. Generate a JSON file containing all required information
#
# # Following this notebook, go to TAFE Files and Course Types and parse TAFE HTML files

# %% [markdown]
# # 1. Import libraries, define input filename, file directory, training.gov.au base url, output directories for HTML files downloaded from training.gov.au and TAFE SA websites

# %%
from bs4 import BeautifulSoup
from copy import deepcopy
from csv import reader, writer
from pprint import pprint

import json
import os
import re
import requests


wd = './tft'
CSV = os.path.join(wd, 'tafe-sa-qualifications---semester-2-2016.csv')
CSV_OUTPUT_FILE = 'new_tafe.csv'
JSON_OUTPUT_FILE = 'tafe-sa-qualifications1.json'
TRAINING_BASE_URL = 'http://training.gov.au/Training/Details/'
TAFE_BASE_URL = 'http://www.tafesa.edu.au/xml/course/aw/'
TF_HTML_DIR = os.path.join(wd, "tf_html/")
TR_HTML_DIR = os.path.join(wd, "tr_html/")

os.chdir(wd)

# %% [markdown]
# # 2. Define helper functions

# %%
def flatmap(array):
    """
    Given a two-dimensional list
    Returns a flattened single-dimension list"""
    return [a for b in array for a in b]

def frequency(array):
    """
    Given a LIST
    Returns a DICTIONARY with list items as keys and frequency as values
    """
    count = {}
    for instance in array:
        fin = instance['url'] 
        if fin in count:
            count[fin] += 1
        else:
            count[fin] = 1
    return count

def index_of_dict(obj, index):
    """
    Given an object and an arbitrary index,
    Returns a dictionary representation of that object at that index. 
    Index is determined by sorting DICTIONARY keys (as strings).
    """
    as_list = sorted(list(obj.keys()))
    key = as_list[index]
    return {
        key: obj[key]
    }

def dict_to_list(dictionary):
    array = []
    for key in dictionary:
        array.append({key: dictionary[key]})
        
    return array

# %% [markdown]
# # 3. Define functions to parse data.sa.gov.au CSV file

# %%
def csv_to_dict(csv_file):
    """
    Takes a file path to a csv file with a specific structure and assumes
    a header row. It depends upon csv.reader and returns a list of dictionaries
    where the keys are the file's header row.
    """
    courses = []

    with open(csv_file, 'r') as f:
        read_file = reader(f)
        headers = next(read_file)
        print(headers)

        for line_index, line in enumerate(read_file):
            course = {}
            course['_id'] = line_index + 1
            
            for index, key in enumerate(headers):
                course[key] = line[index].strip()
            courses.append(course)
    
    return courses
        
    
def add_training_url_to_courses(courses, base_url):
    for course in courses:
        course['training_url'] = base_url + course['National Code']
    return courses
       

def add_tafe_filename_to_courses(courses, base_url):
    start = len(base_url)
    for course in courses:
        course['tafe_filename'] = course['URL'][start:] + '.html'
    return courses

    
def parse_tafe_csv_to_dict(csv_file, training_base_url, tafe_base_url):
    """
    Given a CSV file 'csv_file'
    Calls csv_to_json THEN add_training_url_to_courses THEN add_tafe_filename_to_courses
    Returns a list of course objects
    """
    courses = csv_to_dict(csv_file)
    add_training_url_to_courses(courses, training_base_url)
    add_tafe_filename_to_courses(courses, tafe_base_url)
    return courses

# %% [markdown]
# # 4. Define URL definition functions

# %%
def get_list_of_set_of_training_urls(courses, base_url):
    """
    Given a list of courses,
    finds a unique set of course['National Code'] and
    Returns a list of dictionaries with keys 'National Code' and 'training_url'
    """
    national_codes = [course['National Code'] for course in courses]
    unique_set = list(set(national_codes))
    unique_urls = [{
            'National Code':code, 
            'training_url':base_url + code
        } for code in unique_set]
    
    return unique_urls


def get_list_of_set_of_tafe_urls(courses, base_url):
    """
    Given a list of courses and a base url,
    Returns a list of dictionaries with keys 'url' and 'tafe_filename' distinct on 
    course['tafe_filename'] (which is one-to-one derived from URLs in CSV file)
    """
    
    sorted_set = sorted(list(set([c['tafe_filename'] for c in courses])))
    
    return [{
            'url': base_url + filename[:-5] + '.aspx',
            'tafe_filename': filename
        } for filename in sorted_set]


def inverse_map_url_to_course(courses):
    """
    Given a LIST of courses
    Returns a DICTIONARY with unique tafe_codes as keys and a LIST of _ids as values
    """
    files = {}
    for course in courses:
        try:
            tafe_code = course['tafe_filename'][:-5]
        except KeyError as k:
            print("'tafe_filename'key not present in course.")
            raise Exception
        try:
            _id = course['_id']
        except KeyError as k:
            print("'_id' key not present in course")
        if tafe_code not in files:
            files[tafe_code] = []
            
        # make sure list is unique
        if course['_id'] not in files[tafe_code]:
            files[tafe_code].append(course['_id'])
            
    # sort everything
    for f in files:
        files[f] = sorted(files[f])
    return files

# %% [markdown]
# # 5. Generate list of courses and lists of URLs

# %%
tafe_csv_courses = parse_tafe_csv_to_dict(CSV, TRAINING_BASE_URL, TAFE_BASE_URL)

tf_urls = get_list_of_set_of_tafe_urls(tafe_csv_courses, TAFE_BASE_URL)
tr_urls = get_list_of_set_of_training_urls(tafe_csv_courses, TRAINING_BASE_URL)
# Out:
# ['Course Name', 'National Code', 'Campus', 'Semester', 'Duration Number', 'Duration Scale', 'Study Mode', 'Study Place', 'URL']

# %% [markdown]
# # 6. Define functions that download HTML files from training.gov.au and TAFE SA

# %%
def not_in_directory(filename, directory):
    previous_directory = os.getcwd()
    new_directory = os.chdir(directory)
    filename_in_directory = False
    
    if filename in os.listdir(new_directory):
        filename_in_directory = True
    os.chdir(previous_directory)
    return not(filename_in_directory)
        

def request_generator_comprehension_for_training_urls(urls, directory):
    """
    Takes a list of dictionaries with keys: 'training_url' and 'National Code'
    returns a generator comprehension that when called downloads the url provided
    and returns a dictionary with keys: 'training_url', 'filename' and 'body
    """
    return ({
        'training_url':url['training_url'], 
        'filename': url['National Code'] + '.html', 
        'body': requests.get(url['training_url'], stream=True).text.strip()
        } for url in urls if not_in_directory(url['National Code'] + '.html', directory))


def get_list_of_html_files_in_current_directory():
    return [f for f in os.listdir(os.getcwd()) if f[-5:] == '.html']


def download_tf_htmls(iterator_of_requests, directory):
    previous_directory = os.getcwd()
    new_directory = os.chdir(directory)
    print("Changing directories from " + previous_directory + " to " + directory)
    
    html_files_in_directory = get_list_of_html_files_in_current_directory()
    starting_number_of_html_files_in_directory = len(html_files_in_directory)
    
    i = 0
    for r in iterator_of_requests:
        i += 1
        filename = r['filename']
        
        if filename not in html_files_in_directory:
            with open(filename, 'w') as f:
                body = r['body']
                f.write(body)
                print("("+ str(i) + ")", "Written", filename, "to disk")
    
    final_html_files_in_directory = get_list_of_html_files_in_current_directory()
    final_number_of_html_files_in_directory = len(final_html_files_in_directory)
    number_of_files_saved = final_number_of_html_files_in_directory - starting_number_of_html_files_in_directory
    print(str(number_of_files_saved) + " files saved. Number of files in directory " + str(final_number_of_html_files_in_directory))
    
    print("Returning to " + previous_directory)
    os.chdir(previous_directory)

            
def request_generator_comprehension_for_tafe_pages(urls, directory):
    """
    Takes a list of dictionaries with keys: 'training_url' and 'National Code'
    returns a generator comprehension that when called downloads the url provided
    and returns a dictionary with keys: 'training_url', 'filename' and 'body
    """
    return ({
        'tafe_url':url['url'], 
        'filename': url['tafe_filename'], 
        'body': requests.get(url['url'], stream=True).text.strip()
        } for url in urls if not_in_directory(url['tafe_filename'], directory))

# %% [markdown]
# ## Download training.gov.au pages

# %%
rs = request_generator_comprehension_for_training_urls(tr_urls, TR_HTML_DIR)
download_tf_htmls(rs, TR_HTML_DIR)
# Out:
# Changing directories from /Users/emilkloeden/Documents/Programming/Python/iPython Notebooks/tft/tr_html to /Users/emilkloeden/Documents/Programming/Python/iPython Notebooks/tft/tr_html/
# 0 files saved. Number of files in directory 393
# Returning to /Users/emilkloeden/Documents/Programming/Python/iPython Notebooks/tft/tr_html

# %% [markdown]
# ## Download TAFE SA pages

# %%
tf_urls = get_list_of_set_of_tafe_urls(tafe_courses, TAFE_BASE_URL)

rs = request_generator_comprehension_for_tafe_pages(tf_urls, TF_HTML_DIR)
download_tf_htmls(rs, TF_HTML_DIR)
# Out:
# {'Course Name': 'Advanced Diploma of Accounting', 'Study Place': 'On & Off Campus', 'Duration Scale': 'months', 'URL': 'http://www.tafesa.edu.au/xml/course/aw/aw_TP00726', 'Duration Number': '18', 'Semester': 'Semester 2, 2016', 'National Code': 'FNS60215', 'tafe_filename': 'aw_TP00726.html', 'Campus': 'Adelaide City', '_id': 1, 'Study Mode': 'Full Time & Part Time', 'training_url': 'http://training.gov.au/Training/Details/FNS60215'}
# {'url': 'http://www.tafesa.edu.au/xml/course/aw/aw_AC00004.aspx', 'tafe_filename': 'aw_AC00004.html'}
# 407

# %% [markdown]
# # 7.  Parse training.gov.au files to get ASCED code for each National code

# %%
def parse_tr_html(filename):
    """
    Take a file from training.gov.au (saved to a local location) and return a dictionary
    containing ANZSCO, ASCED and level values
    """
    course = {}
    errors = []

    course['National Code'] = filename[:-5] # 'drop the '.html'
    
    with open(filename, 'r') as f:
        soup = BeautifulSoup(f.read(), "html.parser")

    # declare an empty list so that if the try statement fails
    # the loop below will do nothing
    classifications = [] 
    try:
        div = soup.find('div', id='tableClassifications')
        
        table = div.find('table')
        table_body = table.find('tbody')
        classifications = table_body.find_all('td')
    except AttributeError:
        print(filename, "threw an Attribute error. Check it manually.")
        errors.append({'filename': filename, 'error': 'AttributeError'})

    

    for index, clf in enumerate(classifications):
        if clf.text.strip().startswith('ANZSCO'):
            course['ANZSCO'] = {
                'code': classifications[index + 1].text.strip(), 
                'description': classifications[index + 2].text.strip()
            } 
        elif clf.text.strip().startswith('ASCED'):
            course['ASCED'] = {
                'code': classifications[index + 1].text.strip(), 
                'description': classifications[index + 2].text.strip()
            }
        elif clf.text.strip().startswith('Qualification/Course'):
            course['level'] = {
                'code': classifications[index + 1].text.strip(), 
                'description': classifications[index + 2].text.strip()
            }
    
    return {'course':course, 'errors': errors}
    

def parse_list_of_tr_html(directory):
    """
    Parse a directory of training.gov.au html files
    """
    previous_directory = os.getcwd()
    new_directory = os.chdir(directory)
    output = []
    what = []

    for f in os.listdir():
        file_output = parse_tr_html(f)
        if file_output:
            output.append(file_output)
        else:
            what.append(f)
            
    
    courses = [o['course'] for o in output]
    errors = [o['errors'] for o in output]
    
    return {'courses':courses, 'errors':errors, 'what': what}

# %% [markdown]
# ## Run parsing functions on training.gov.au files

# %%
# Because i don't know how to do destructuring in python
tr_output = parse_list_of_tr_html(TR_HTML_DIR)

training_courses = tr_output['courses']
training_errors = flatmap(tr_output['errors']) #[subitem for item in tr_output['errors'] for subitem in item]
training_what = tr_output['what']

print(len(training_courses))
print(training_errors)
print(training_what)
# Out:
# 10251NAT.html threw an Attribute error. Check it manually.
# 10252NAT.html threw an Attribute error. Check it manually.
# 10253NAT.html threw an Attribute error. Check it manually.
# 10254NAT.html threw an Attribute error. Check it manually.
# 10255NAT.html threw an Attribute error. Check it manually.
# 10257NAT.html threw an Attribute error. Check it manually.
# 10260NAT.html threw an Attribute error. Check it manually.
# 10262NAT.html threw an Attribute error. Check it manually.
# 10263NAT.html threw an Attribute error. Check it manually.
# 10266NAT.html threw an Attribute error. Check it manually.
# 10267NAT.html threw an Attribute error. Check it manually.
# 10268NAT.html threw an Attribute error. Check it manually.
# 10269NAT.html threw an Attribute error. Check it manually.
# 10270NAT.html threw an Attribute error. Check it manually.
# 40649SA.html threw an Attribute error. Check it manually.
# 40650SA.html threw an Attribute error. Check it manually.
# CRS1400029.html threw an Attribute error. Check it manually.
# MEASS00443.html threw an Attribute error. Check it manually.
# TAESS00009.html threw an Attribute error. Check it manually.
# UEESS00048.html threw an Attribute error. Check it manually.
# UEESS00051.html threw an Attribute error. Check it manually.
# UEESS00052.html threw an Attribute error. Check it manually.
# 393
# [{'error': 'AttributeError', 'filename': '10251NAT.html'}, {'error': 'AttributeError', 'filename': '10252NAT.html'}, {'error': 'AttributeError', 'filename': '10253NAT.html'}, {'error': 'AttributeError', 'filename': '10254NAT.html'}, {'error': 'AttributeError', 'filename': '10255NAT.html'}, {'error': 'AttributeError', 'filename': '10257NAT.html'}, {'error': 'AttributeError', 'filename': '10260NAT.html'}, {'error': 'AttributeError', 'filename': '10262NAT.html'}, {'error': 'AttributeError', 'filename': '10263NAT.html'}, {'error': 'AttributeError', 'filename': '10266NAT.html'}, {'error': 'AttributeError', 'filename': '10267NAT.html'}, {'error': 'AttributeError', 'filename': '10268NAT.html'}, {'error': 'AttributeError', 'filename': '10269NAT.html'}, {'error': 'AttributeError', 'filename': '10270NAT.html'}, {'error': 'AttributeError', 'filename': '40649SA.html'}, {'error': 'AttributeError', 'filename': '40650SA.html'}, {'error': 'AttributeError', 'filename': 'CRS1400029.html'}, {'error': 'AttributeError', 'filename': 'MEASS00443.html'}, {'error': 'AttributeError', 'filename': 'TAESS00009.html'}, {'error': 'AttributeError', 'filename': 'UEESS00048.html'}, {'error': 'AttributeError', 'filename': 'UEESS00051.html'}, {'error': 'AttributeError', 'filename': 'UEESS00052.html'}]
# []

# %% [markdown]
# # 8. Define functions that will parse saved .html files from TAFE SA website

# %%
def get_element_by_string(soup, element_type, string):
    """
    Given a soup, a string indicating an HTML element type 'type' and a keyword 'string'
    Returns a bs4.tag element representing the first HTML element of type 'type' 
    containing text matching '%string%'
    """
    return soup.find(element_type, string=re.compile(string))


def get_course_types_no_try(soup):
    """
    Given a soup,
    Returns a LIST of course types
    """
    return [el.text.strip() for el in soup.find(id="course-type").find_all("li")]


def get_admission_requirements_no_try(soup):
    """
    Given a soup,
    Returns a LIST of Course Admission Requirements
    """
    # find a very specific div
    div = soup.find('div', class_ = 'course_table_box')

    # find the first h3 element inside the div
    h3 = div.find('h3')

    # find and return all li elements next to the h3
    return [el.text.strip() for el in h3.next_sibling.find_all('li')]


def get_TAFE_SA_code_no_try(soup):
    """
    Given a soup,
    Returns a STRING stating the course code TAFE gives on the page
    """
    table = soup.find("table", "course_summary")
    key = table.find("th", string=re.compile("TAFE SA Code"))
    value = key.next_sibling.text.strip()

    return value


def get_course_notes_no_try(soup):
    """
    Given a soup,
    Returns a LIST of course notes
    """
    header = get_element_by_string(soup, "h2", "Course Notes")
    notes_element = header.next_sibling
    notes = [el.text.strip() for el in notes_element.find_all('li')]

    return notes
    

def parse_file(filename):
    """
    Given a filename and assuming the file exists in the current directory,
    Returns a dictionary containing the following keys:
    * filename
    * national_code
    [* TAFE_SA_code]
    [* course_notes]
    [* course_types]
    [* admission_requirements]
    """
    with open(filename, 'r') as f:
        course = {}
        course['filename'] = filename
        # Get Soup for file
        soup = BeautifulSoup(f.read(), "html.parser")
    try:
        course['TAFE_SA_code'] = get_TAFE_SA_code_no_try(soup)
    except AttributeError:
        print(filename, ": unable to find TAFE SA Code. Investigate manually.") 
        
    try:
        course['course_notes'] = get_course_notes_no_try(soup)
    except AttributeError:
        print(filename, ": unable to find course notes. Investigate manually.")
        
    
    try:
        course['course_types'] = get_course_types_no_try(soup)
    except AttributeError:
        print(filename, ": unable to find course type. Investigate manually.")
        
    try:
        course['admission_requirements'] = get_admission_requirements_no_try(soup)
    except AttributeError:
        print(filename, ": unable to find Course Admission Requirements. Investigate manually.")  

    return course


def parse_files(files):
    """
    Given a list of filenames
    Returns a LIST of course objects created by calling parse_file on each file with '.html' extension
    """
    length = len(files)
    courses = []
    
    for index, filename in enumerate(files):
        if filename[-5:] == '.html':  # Only open html files
            print("Parsing " + filename + " (" + str(index + 1) + " of " + str(length) + " files).")
            course = parse_file(filename)
            courses.append(course)
    
    return courses


def parse_directory(directory):
    """
    (Wrapper over parse_files)
    Given a directory path,
    Returns a LIST of course objects created by calling parse_file on each file with '.html' extension
    """
    previous_directory = os.getcwd()
    new_directory = os.chdir(directory)
    files = os.listdir(os.getcwd())
    
    courses =  parse_files(files)
    os.chdir(previous_directory)

    return courses

# %% [markdown]
# # 9. Parse HTML files in memory into a list of dictionary objects

# %%
tafe_courses = parse_directory(TF_HTML_DIR)
tafe_filenames_and_their_courses = inverse_map_url_to_course(tafe_csv_courses)
# Out:
# Parsing aw_AC00004.html (0 of 407 files).
# Parsing aw_AC00024.html (1 of 407 files).
# Parsing aw_AC00034.html (2 of 407 files).
# aw_AC00034.html : unable to find course notes. Investigate manually.
# Parsing aw_AC00035.html (3 of 407 files).
# aw_AC00035.html : unable to find course notes. Investigate manually.
# Parsing aw_AC00040.html (4 of 407 files).
# Parsing aw_AC00041.html (5 of 407 files).
# Parsing aw_AC00042.html (6 of 407 files).
# Parsing aw_AC00043.html (7 of 407 files).
# Parsing aw_AC00045.html (8 of 407 files).
# Parsing aw_AC00057.html (9 of 407 files).
# Parsing aw_AC00058.html (10 of 407 files).
# Parsing aw_AC00059.html (11 of 407 files).
# Parsing aw_AC00061.html (12 of 407 files).
# Parsing aw_AC00062.html (13 of 407 files).
# aw_AC00062.html : unable to find course notes. Investigate manually.
# Parsing aw_AC00063.html (14 of 407 files).
# aw_AC00063.html : unable to find course notes. Investigate manually.
# Parsing aw_AC00064.html (15 of 407 files).
# aw_AC00064.html : unable to find course notes. Investigate manually.
# Parsing aw_AC00065.html (16 of 407 files).
# aw_AC00065.html : unable to find course notes. Investigate manually.
# Parsing aw_AC00067.html (17 of 407 files).
# Parsing aw_AC00069.html (18 of 407 files).
# aw_AC00069.html : unable to find course notes. Investigate manually.
# Parsing aw_AC00071.html (19 of 407 files).
# Parsing aw_AC00072.html (20 of 407 files).
# aw_AC00072.html : unable to find course notes. Investigate manually.
# Parsing aw_AZB.html (21 of 407 files).
# Parsing aw_BPL.html (22 of 407 files).
# Parsing aw_ECB.html (23 of 407 files).
# Parsing aw_ECC.html (24 of 407 files).
# Parsing aw_ECS.html (25 of 407 files).
# Parsing aw_ECT.html (26 of 407 files).
# Parsing aw_ECW.html (27 of 407 files).
# Parsing aw_ECX.html (28 of 407 files).
# Parsing aw_ELT.html (29 of 407 files).
# aw_ELT.html : unable to find TAFE SA Code. Investigate manually.
# aw_ELT.html : unable to find course notes. Investigate manually.
# aw_ELT.html : unable to find course type. Investigate manually.
# aw_ELT.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_ELW.html (30 of 407 files).
# aw_ELW.html : unable to find TAFE SA Code. Investigate manually.
# aw_ELW.html : unable to find course notes. Investigate manually.
# aw_ELW.html : unable to find course type. Investigate manually.
# aw_ELW.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_ELX.html (31 of 407 files).
# aw_ELX.html : unable to find TAFE SA Code. Investigate manually.
# aw_ELX.html : unable to find course notes. Investigate manually.
# aw_ELX.html : unable to find course type. Investigate manually.
# aw_ELX.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_ELY.html (32 of 407 files).
# aw_ELY.html : unable to find TAFE SA Code. Investigate manually.
# aw_ELY.html : unable to find course notes. Investigate manually.
# aw_ELY.html : unable to find course type. Investigate manually.
# aw_ELY.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_EZN.html (33 of 407 files).
# aw_EZN.html : unable to find TAFE SA Code. Investigate manually.
# aw_EZN.html : unable to find course notes. Investigate manually.
# aw_EZN.html : unable to find course type. Investigate manually.
# aw_EZN.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_EZP.html (34 of 407 files).
# aw_EZP.html : unable to find TAFE SA Code. Investigate manually.
# aw_EZP.html : unable to find course notes. Investigate manually.
# aw_EZP.html : unable to find course type. Investigate manually.
# aw_EZP.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_FYS.html (35 of 407 files).
# Parsing aw_FYT.html (36 of 407 files).
# Parsing aw_FZD.html (37 of 407 files).
# Parsing aw_HFP.html (38 of 407 files).
# Parsing aw_HGY.html (39 of 407 files).
# aw_HGY.html : unable to find course notes. Investigate manually.
# Parsing aw_HGZ.html (40 of 407 files).
# Parsing aw_MRP.html (41 of 407 files).
# aw_MRP.html : unable to find course notes. Investigate manually.
# Parsing aw_MSD.html (42 of 407 files).
# Parsing aw_MSE.html (43 of 407 files).
# Parsing aw_MSF.html (44 of 407 files).
# Parsing aw_MSG.html (45 of 407 files).
# aw_MSG.html : unable to find course notes. Investigate manually.
# Parsing aw_MSL.html (46 of 407 files).
# Parsing aw_MSM.html (47 of 407 files).
# Parsing aw_MSR.html (48 of 407 files).
# Parsing aw_MSW.html (49 of 407 files).
# Parsing aw_NBC.html (50 of 407 files).
# Parsing aw_NTB.html (51 of 407 files).
# Parsing aw_NTD.html (52 of 407 files).
# aw_NTD.html : unable to find course notes. Investigate manually.
# aw_NTD.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_NTE.html (53 of 407 files).
# aw_NTE.html : unable to find course notes. Investigate manually.
# aw_NTE.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_NTG.html (54 of 407 files).
# aw_NTG.html : unable to find course notes. Investigate manually.
# aw_NTG.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_NTK.html (55 of 407 files).
# aw_NTK.html : unable to find course notes. Investigate manually.
# Parsing aw_NTL.html (56 of 407 files).
# aw_NTL.html : unable to find course notes. Investigate manually.
# Parsing aw_RZF.html (57 of 407 files).
# aw_RZF.html : unable to find course notes. Investigate manually.
# Parsing aw_RZG.html (58 of 407 files).
# Parsing aw_SAC.html (59 of 407 files).
# Parsing aw_SAH.html (60 of 407 files).
# Parsing aw_SAP.html (61 of 407 files).
# aw_SAP.html : unable to find course notes. Investigate manually.
# Parsing aw_SK00022.html (62 of 407 files).
# aw_SK00022.html : unable to find course notes. Investigate manually.
# aw_SK00022.html : unable to find course type. Investigate manually.
# Parsing aw_SK00024.html (63 of 407 files).
# aw_SK00024.html : unable to find course notes. Investigate manually.
# aw_SK00024.html : unable to find course type. Investigate manually.
# Parsing aw_SK00025.html (64 of 407 files).
# aw_SK00025.html : unable to find course notes. Investigate manually.
# aw_SK00025.html : unable to find course type. Investigate manually.
# Parsing aw_SK00058.html (65 of 407 files).
# aw_SK00058.html : unable to find course type. Investigate manually.
# Parsing aw_SK00067.html (66 of 407 files).
# aw_SK00067.html : unable to find course notes. Investigate manually.
# aw_SK00067.html : unable to find course type. Investigate manually.
# Parsing aw_TP00008.html (67 of 407 files).
# Parsing aw_TP00009.html (68 of 407 files).
# Parsing aw_TP00011.html (69 of 407 files).
# aw_TP00011.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00023.html (70 of 407 files).
# Parsing aw_TP00024.html (71 of 407 files).
# Parsing aw_TP00025.html (72 of 407 files).
# aw_TP00025.html : unable to find course notes. Investigate manually.
# aw_TP00025.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00026.html (73 of 407 files).
# Parsing aw_TP00027.html (74 of 407 files).
# Parsing aw_TP00029.html (75 of 407 files).
# Parsing aw_TP00033.html (76 of 407 files).
# Parsing aw_TP00034.html (77 of 407 files).
# Parsing aw_TP00035.html (78 of 407 files).
# aw_TP00035.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00037.html (79 of 407 files).
# Parsing aw_TP00038.html (80 of 407 files).
# aw_TP00038.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00048.html (81 of 407 files).
# Parsing aw_TP00053.html (82 of 407 files).
# Parsing aw_TP00055.html (83 of 407 files).
# Parsing aw_TP00058.html (84 of 407 files).
# aw_TP00058.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00061.html (85 of 407 files).
# aw_TP00061.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00062.html (86 of 407 files).
# Parsing aw_TP00063.html (87 of 407 files).
# Parsing aw_TP00074.html (88 of 407 files).
# aw_TP00074.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00078.html (89 of 407 files).
# Parsing aw_TP00079.html (90 of 407 files).
# Parsing aw_TP00125.html (91 of 407 files).
# Parsing aw_TP00126.html (92 of 407 files).
# Parsing aw_TP00138.html (93 of 407 files).
# Parsing aw_TP00141.html (94 of 407 files).
# Parsing aw_TP00142.html (95 of 407 files).
# Parsing aw_TP00143.html (96 of 407 files).
# Parsing aw_TP00144.html (97 of 407 files).
# Parsing aw_TP00145.html (98 of 407 files).
# Parsing aw_TP00146.html (99 of 407 files).
# Parsing aw_TP00147.html (100 of 407 files).
# Parsing aw_TP00149.html (101 of 407 files).
# Parsing aw_TP00151.html (102 of 407 files).
# Parsing aw_TP00153.html (103 of 407 files).
# Parsing aw_TP00157.html (104 of 407 files).
# Parsing aw_TP00158.html (105 of 407 files).
# Parsing aw_TP00166.html (106 of 407 files).
# Parsing aw_TP00168.html (107 of 407 files).
# Parsing aw_TP00169.html (108 of 407 files).
# Parsing aw_TP00171.html (109 of 407 files).
# Parsing aw_TP00174.html (110 of 407 files).
# Parsing aw_TP00181.html (111 of 407 files).
# aw_TP00181.html : unable to find TAFE SA Code. Investigate manually.
# aw_TP00181.html : unable to find course notes. Investigate manually.
# aw_TP00181.html : unable to find course type. Investigate manually.
# aw_TP00181.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00182.html (112 of 407 files).
# Parsing aw_TP00183.html (113 of 407 files).
# Parsing aw_TP00195.html (114 of 407 files).
# Parsing aw_TP00196.html (115 of 407 files).
# Parsing aw_TP00203.html (116 of 407 files).
# Parsing aw_TP00204.html (117 of 407 files).
# Parsing aw_TP00206.html (118 of 407 files).
# Parsing aw_TP00211.html (119 of 407 files).
# aw_TP00211.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00212.html (120 of 407 files).
# aw_TP00212.html : unable to find course notes. Investigate manually.
# aw_TP00212.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00213.html (121 of 407 files).
# aw_TP00213.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00214.html (122 of 407 files).
# aw_TP00214.html : unable to find course notes. Investigate manually.
# aw_TP00214.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00215.html (123 of 407 files).
# aw_TP00215.html : unable to find course notes. Investigate manually.
# aw_TP00215.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00216.html (124 of 407 files).
# aw_TP00216.html : unable to find course notes. Investigate manually.
# aw_TP00216.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00217.html (125 of 407 files).
# Parsing aw_TP00219.html (126 of 407 files).
# Parsing aw_TP00220.html (127 of 407 files).
# Parsing aw_TP00224.html (128 of 407 files).
# Parsing aw_TP00225.html (129 of 407 files).
# Parsing aw_TP00226.html (130 of 407 files).
# Parsing aw_TP00229.html (131 of 407 files).
# aw_TP00229.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00230.html (132 of 407 files).
# Parsing aw_TP00231.html (133 of 407 files).
# Parsing aw_TP00232.html (134 of 407 files).
# Parsing aw_TP00234.html (135 of 407 files).
# Parsing aw_TP00235.html (136 of 407 files).
# Parsing aw_TP00236.html (137 of 407 files).
# aw_TP00236.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00244.html (138 of 407 files).
# Parsing aw_TP00247.html (139 of 407 files).
# Parsing aw_TP00248.html (140 of 407 files).
# Parsing aw_TP00254.html (141 of 407 files).
# aw_TP00254.html : unable to find course notes. Investigate manually.
# aw_TP00254.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00258.html (142 of 407 files).
# aw_TP00258.html : unable to find course notes. Investigate manually.
# aw_TP00258.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00260.html (143 of 407 files).
# aw_TP00260.html : unable to find course notes. Investigate manually.
# aw_TP00260.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00261.html (144 of 407 files).
# aw_TP00261.html : unable to find course notes. Investigate manually.
# aw_TP00261.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00262.html (145 of 407 files).
# aw_TP00262.html : unable to find course notes. Investigate manually.
# aw_TP00262.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00263.html (146 of 407 files).
# aw_TP00263.html : unable to find course notes. Investigate manually.
# aw_TP00263.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00267.html (147 of 407 files).
# aw_TP00267.html : unable to find course notes. Investigate manually.
# aw_TP00267.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00276.html (148 of 407 files).
# aw_TP00276.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00277.html (149 of 407 files).
# Parsing aw_TP00291.html (150 of 407 files).
# aw_TP00291.html : unable to find course notes. Investigate manually.
# aw_TP00291.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00292.html (151 of 407 files).
# Parsing aw_TP00297.html (152 of 407 files).
# Parsing aw_TP00299.html (153 of 407 files).
# Parsing aw_TP00326.html (154 of 407 files).
# aw_TP00326.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00330.html (155 of 407 files).
# Parsing aw_TP00350.html (156 of 407 files).
# aw_TP00350.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00351.html (157 of 407 files).
# Parsing aw_TP00353.html (158 of 407 files).
# Parsing aw_TP00355.html (159 of 407 files).
# Parsing aw_TP00356.html (160 of 407 files).
# Parsing aw_TP00357.html (161 of 407 files).
# Parsing aw_TP00358.html (162 of 407 files).
# Parsing aw_TP00359.html (163 of 407 files).
# Parsing aw_TP00360.html (164 of 407 files).
# Parsing aw_TP00383.html (165 of 407 files).
# Parsing aw_TP00384.html (166 of 407 files).
# aw_TP00384.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00385.html (167 of 407 files).
# Parsing aw_TP00386.html (168 of 407 files).
# Parsing aw_TP00387.html (169 of 407 files).
# Parsing aw_TP00388.html (170 of 407 files).
# aw_TP00388.html : unable to find course notes. Investigate manually.
# aw_TP00388.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00389.html (171 of 407 files).
# aw_TP00389.html : unable to find course notes. Investigate manually.
# aw_TP00389.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00390.html (172 of 407 files).
# Parsing aw_TP00391.html (173 of 407 files).
# Parsing aw_TP00392.html (174 of 407 files).
# Parsing aw_TP00395.html (175 of 407 files).
# aw_TP00395.html : unable to find course notes. Investigate manually.
# aw_TP00395.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00413.html (176 of 407 files).
# Parsing aw_TP00420.html (177 of 407 files).
# Parsing aw_TP00421.html (178 of 407 files).
# Parsing aw_TP00422.html (179 of 407 files).
# aw_TP00422.html : unable to find course notes. Investigate manually.
# aw_TP00422.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00423.html (180 of 407 files).
# aw_TP00423.html : unable to find course notes. Investigate manually.
# aw_TP00423.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00424.html (181 of 407 files).
# Parsing aw_TP00429.html (182 of 407 files).
# Parsing aw_TP00430.html (183 of 407 files).
# Parsing aw_TP00431.html (184 of 407 files).
# Parsing aw_TP00432.html (185 of 407 files).
# Parsing aw_TP00437.html (186 of 407 files).
# Parsing aw_TP00453.html (187 of 407 files).
# aw_TP00453.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00454.html (188 of 407 files).
# aw_TP00454.html : unable to find TAFE SA Code. Investigate manually.
# aw_TP00454.html : unable to find course notes. Investigate manually.
# aw_TP00454.html : unable to find course type. Investigate manually.
# aw_TP00454.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00460.html (189 of 407 files).
# Parsing aw_TP00463.html (190 of 407 files).
# Parsing aw_TP00466.html (191 of 407 files).
# Parsing aw_TP00469.html (192 of 407 files).
# aw_TP00469.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00472.html (193 of 407 files).
# aw_TP00472.html : unable to find course notes. Investigate manually.
# aw_TP00472.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00476.html (194 of 407 files).
# Parsing aw_TP00478.html (195 of 407 files).
# Parsing aw_TP00482.html (196 of 407 files).
# Parsing aw_TP00483.html (197 of 407 files).
# Parsing aw_TP00486.html (198 of 407 files).
# aw_TP00486.html : unable to find course notes. Investigate manually.
# aw_TP00486.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00489.html (199 of 407 files).
# Parsing aw_TP00501.html (200 of 407 files).
# Parsing aw_TP00502.html (201 of 407 files).
# Parsing aw_TP00521.html (202 of 407 files).
# aw_TP00521.html : unable to find course notes. Investigate manually.
# aw_TP00521.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00522.html (203 of 407 files).
# Parsing aw_TP00524.html (204 of 407 files).
# Parsing aw_TP00530.html (205 of 407 files).
# Parsing aw_TP00531.html (206 of 407 files).
# aw_TP00531.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00535.html (207 of 407 files).
# Parsing aw_TP00536.html (208 of 407 files).
# Parsing aw_TP00537.html (209 of 407 files).
# Parsing aw_TP00538.html (210 of 407 files).
# Parsing aw_TP00539.html (211 of 407 files).
# Parsing aw_TP00540.html (212 of 407 files).
# Parsing aw_TP00542.html (213 of 407 files).
# aw_TP00542.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00544.html (214 of 407 files).
# Parsing aw_TP00545.html (215 of 407 files).
# Parsing aw_TP00547.html (216 of 407 files).
# Parsing aw_TP00548.html (217 of 407 files).
# aw_TP00548.html : unable to find course notes. Investigate manually.
# aw_TP00548.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00549.html (218 of 407 files).
# Parsing aw_TP00552.html (219 of 407 files).
# Parsing aw_TP00559.html (220 of 407 files).
# aw_TP00559.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00561.html (221 of 407 files).
# Parsing aw_TP00569.html (222 of 407 files).
# Parsing aw_TP00575.html (223 of 407 files).
# aw_TP00575.html : unable to find course notes. Investigate manually.
# aw_TP00575.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00577.html (224 of 407 files).
# aw_TP00577.html : unable to find course notes. Investigate manually.
# aw_TP00577.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00579.html (225 of 407 files).
# aw_TP00579.html : unable to find course notes. Investigate manually.
# aw_TP00579.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00581.html (226 of 407 files).
# aw_TP00581.html : unable to find course notes. Investigate manually.
# aw_TP00581.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00582.html (227 of 407 files).
# aw_TP00582.html : unable to find course notes. Investigate manually.
# aw_TP00582.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00585.html (228 of 407 files).
# aw_TP00585.html : unable to find course notes. Investigate manually.
# aw_TP00585.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00586.html (229 of 407 files).
# aw_TP00586.html : unable to find course notes. Investigate manually.
# aw_TP00586.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00595.html (230 of 407 files).
# aw_TP00595.html : unable to find course notes. Investigate manually.
# aw_TP00595.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00596.html (231 of 407 files).
# Parsing aw_TP00603.html (232 of 407 files).
# aw_TP00603.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00604.html (233 of 407 files).
# aw_TP00604.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00605.html (234 of 407 files).
# aw_TP00605.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00606.html (235 of 407 files).
# aw_TP00606.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00607.html (236 of 407 files).
# aw_TP00607.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00612.html (237 of 407 files).
# Parsing aw_TP00613.html (238 of 407 files).
# aw_TP00613.html : unable to find course notes. Investigate manually.
# aw_TP00613.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00614.html (239 of 407 files).
# aw_TP00614.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00615.html (240 of 407 files).
# Parsing aw_TP00620.html (241 of 407 files).
# Parsing aw_TP00622.html (242 of 407 files).
# Parsing aw_TP00623.html (243 of 407 files).
# Parsing aw_TP00624.html (244 of 407 files).
# Parsing aw_TP00625.html (245 of 407 files).
# Parsing aw_TP00626.html (246 of 407 files).
# Parsing aw_TP00628.html (247 of 407 files).
# Parsing aw_TP00629.html (248 of 407 files).
# Parsing aw_TP00632.html (249 of 407 files).
# aw_TP00632.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00633.html (250 of 407 files).
# Parsing aw_TP00634.html (251 of 407 files).
# Parsing aw_TP00635.html (252 of 407 files).
# Parsing aw_TP00636.html (253 of 407 files).
# Parsing aw_TP00638.html (254 of 407 files).
# Parsing aw_TP00639.html (255 of 407 files).
# Parsing aw_TP00640.html (256 of 407 files).
# aw_TP00640.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00641.html (257 of 407 files).
# aw_TP00641.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00642.html (258 of 407 files).
# aw_TP00642.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00644.html (259 of 407 files).
# Parsing aw_TP00645.html (260 of 407 files).
# Parsing aw_TP00646.html (261 of 407 files).
# Parsing aw_TP00647.html (262 of 407 files).
# Parsing aw_TP00657.html (263 of 407 files).
# aw_TP00657.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00660.html (264 of 407 files).
# Parsing aw_TP00661.html (265 of 407 files).
# Parsing aw_TP00662.html (266 of 407 files).
# Parsing aw_TP00663.html (267 of 407 files).
# Parsing aw_TP00664.html (268 of 407 files).
# Parsing aw_TP00666.html (269 of 407 files).
# Parsing aw_TP00671.html (270 of 407 files).
# Parsing aw_TP00673.html (271 of 407 files).
# Parsing aw_TP00681.html (272 of 407 files).
# Parsing aw_TP00682.html (273 of 407 files).
# Parsing aw_TP00685.html (274 of 407 files).
# Parsing aw_TP00686.html (275 of 407 files).
# Parsing aw_TP00688.html (276 of 407 files).
# aw_TP00688.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00689.html (277 of 407 files).
# Parsing aw_TP00690.html (278 of 407 files).
# aw_TP00690.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00691.html (279 of 407 files).
# Parsing aw_TP00693.html (280 of 407 files).
# aw_TP00693.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00694.html (281 of 407 files).
# aw_TP00694.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00695.html (282 of 407 files).
# Parsing aw_TP00696.html (283 of 407 files).
# Parsing aw_TP00697.html (284 of 407 files).
# Parsing aw_TP00698.html (285 of 407 files).
# Parsing aw_TP00702.html (286 of 407 files).
# aw_TP00702.html : unable to find course notes. Investigate manually.
# aw_TP00702.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00703.html (287 of 407 files).
# aw_TP00703.html : unable to find course notes. Investigate manually.
# aw_TP00703.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00704.html (288 of 407 files).
# aw_TP00704.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00708.html (289 of 407 files).
# Parsing aw_TP00709.html (290 of 407 files).
# Parsing aw_TP00711.html (291 of 407 files).
# Parsing aw_TP00712.html (292 of 407 files).
# Parsing aw_TP00713.html (293 of 407 files).
# aw_TP00713.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00714.html (294 of 407 files).
# aw_TP00714.html : unable to find course notes. Investigate manually.
# aw_TP00714.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00715.html (295 of 407 files).
# Parsing aw_TP00716.html (296 of 407 files).
# Parsing aw_TP00717.html (297 of 407 files).
# Parsing aw_TP00718.html (298 of 407 files).
# aw_TP00718.html : unable to find course notes. Investigate manually.
# aw_TP00718.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00720.html (299 of 407 files).
# Parsing aw_TP00721.html (300 of 407 files).
# Parsing aw_TP00722.html (301 of 407 files).
# Parsing aw_TP00723.html (302 of 407 files).
# Parsing aw_TP00724.html (303 of 407 files).
# Parsing aw_TP00725.html (304 of 407 files).
# Parsing aw_TP00726.html (305 of 407 files).
# Parsing aw_TP00727.html (306 of 407 files).
# Parsing aw_TP00728.html (307 of 407 files).
# Parsing aw_TP00729.html (308 of 407 files).
# Parsing aw_TP00730.html (309 of 407 files).
# Parsing aw_TP00731.html (310 of 407 files).
# Parsing aw_TP00732.html (311 of 407 files).
# Parsing aw_TP00733.html (312 of 407 files).
# Parsing aw_TP00734.html (313 of 407 files).
# Parsing aw_TP00735.html (314 of 407 files).
# Parsing aw_TP00736.html (315 of 407 files).
# aw_TP00736.html : unable to find course notes. Investigate manually.
# aw_TP00736.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00737.html (316 of 407 files).
# Parsing aw_TP00739.html (317 of 407 files).
# Parsing aw_TP00740.html (318 of 407 files).
# Parsing aw_TP00741.html (319 of 407 files).
# Parsing aw_TP00742.html (320 of 407 files).
# Parsing aw_TP00748.html (321 of 407 files).
# Parsing aw_TP00749.html (322 of 407 files).
# Parsing aw_TP00750.html (323 of 407 files).
# Parsing aw_TP00751.html (324 of 407 files).
# Parsing aw_TP00753.html (325 of 407 files).
# Parsing aw_TP00754.html (326 of 407 files).
# Parsing aw_TP00758.html (327 of 407 files).
# Parsing aw_TP00759.html (328 of 407 files).
# Parsing aw_TP00760.html (329 of 407 files).
# Parsing aw_TP00761.html (330 of 407 files).
# Parsing aw_TP00762.html (331 of 407 files).
# Parsing aw_TP00763.html (332 of 407 files).
# Parsing aw_TP00764.html (333 of 407 files).
# Parsing aw_TP00765.html (334 of 407 files).
# Parsing aw_TP00766.html (335 of 407 files).
# Parsing aw_TP00767.html (336 of 407 files).
# Parsing aw_TP00768.html (337 of 407 files).
# Parsing aw_TP00769.html (338 of 407 files).
# Parsing aw_TP00770.html (339 of 407 files).
# Parsing aw_TP00771.html (340 of 407 files).
# Parsing aw_TP00772.html (341 of 407 files).
# Parsing aw_TP00773.html (342 of 407 files).
# Parsing aw_TP00774.html (343 of 407 files).
# Parsing aw_TP00775.html (344 of 407 files).
# Parsing aw_TP00776.html (345 of 407 files).
# Parsing aw_TP00778.html (346 of 407 files).
# Parsing aw_TP00779.html (347 of 407 files).
# Parsing aw_TP00780.html (348 of 407 files).
# Parsing aw_TP00781.html (349 of 407 files).
# Parsing aw_TP00782.html (350 of 407 files).
# Parsing aw_TP00783.html (351 of 407 files).
# Parsing aw_TP00784.html (352 of 407 files).
# Parsing aw_TP00785.html (353 of 407 files).
# Parsing aw_TP00786.html (354 of 407 files).
# Parsing aw_TP00787.html (355 of 407 files).
# Parsing aw_TP00788.html (356 of 407 files).
# Parsing aw_TP00789.html (357 of 407 files).
# Parsing aw_TP00790.html (358 of 407 files).
# Parsing aw_TP00791.html (359 of 407 files).
# aw_TP00791.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00792.html (360 of 407 files).
# aw_TP00792.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00793.html (361 of 407 files).
# Parsing aw_TP00795.html (362 of 407 files).
# Parsing aw_TP00796.html (363 of 407 files).
# Parsing aw_TP00797.html (364 of 407 files).
# Parsing aw_TP00798.html (365 of 407 files).
# Parsing aw_TP00800.html (366 of 407 files).
# Parsing aw_TP00801.html (367 of 407 files).
# Parsing aw_TP00802.html (368 of 407 files).
# aw_TP00802.html : unable to find course notes. Investigate manually.
# aw_TP00802.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00803.html (369 of 407 files).
# Parsing aw_TP00804.html (370 of 407 files).
# Parsing aw_TP00805.html (371 of 407 files).
# Parsing aw_TP00808.html (372 of 407 files).
# aw_TP00808.html : unable to find course notes. Investigate manually.
# aw_TP00808.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00809.html (373 of 407 files).
# aw_TP00809.html : unable to find course notes. Investigate manually.
# aw_TP00809.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00810.html (374 of 407 files).
# aw_TP00810.html : unable to find course notes. Investigate manually.
# aw_TP00810.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00811.html (375 of 407 files).
# Parsing aw_TP00812.html (376 of 407 files).
# aw_TP00812.html : unable to find course notes. Investigate manually.
# aw_TP00812.html : unable to find Course Admission Requirements. Investigate manually.
# Parsing aw_TP00819.html (377 of 407 files).
# aw_TP00819.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00821.html (378 of 407 files).
# aw_TP00821.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00824.html (379 of 407 files).
# Parsing aw_TP00825.html (380 of 407 files).
# aw_TP00825.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00826.html (381 of 407 files).
# aw_TP00826.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00827.html (382 of 407 files).
# Parsing aw_TP00828.html (383 of 407 files).
# aw_TP00828.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00829.html (384 of 407 files).
# aw_TP00829.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00831.html (385 of 407 files).
# Parsing aw_TP00832.html (386 of 407 files).
# aw_TP00832.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00833.html (387 of 407 files).
# Parsing aw_TP00835.html (388 of 407 files).
# aw_TP00835.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00836.html (389 of 407 files).
# aw_TP00836.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00837.html (390 of 407 files).
# aw_TP00837.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00838.html (391 of 407 files).
# Parsing aw_TP00839.html (392 of 407 files).
# aw_TP00839.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00841.html (393 of 407 files).
# Parsing aw_TP00842.html (394 of 407 files).
# Parsing aw_TP00843.html (395 of 407 files).
# Parsing aw_TP00844.html (396 of 407 files).
# Parsing aw_TP00845.html (397 of 407 files).
# Parsing aw_TP00846.html (398 of 407 files).
# Parsing aw_TP00855.html (399 of 407 files).
# Parsing aw_TP00857.html (400 of 407 files).
# Parsing aw_TP00868.html (401 of 407 files).
# aw_TP00868.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00869.html (402 of 407 files).
# Parsing aw_TP00870.html (403 of 407 files).
# aw_TP00870.html : unable to find course notes. Investigate manually.
# Parsing aw_TP00871.html (404 of 407 files).
# Parsing aw_TP00878.html (405 of 407 files).
# Parsing aw_XRC.html (406 of 407 files).

# %% [markdown]
# # 10. Merge all three datasets (CSV, training.gov.au, and TAFE SA webpages)

# %%
def merge_three_datasets(tafe_csv_courses, training_courses, tafe_courses):
    merged_courses = []
    for tafe_csv_course in tafe_csv_courses:
        for training_course in training_courses:
            if training_course['National Code'] == tafe_csv_course['National Code']:
                for tafe_course in tafe_courses:
                    if tafe_course['filename'] == tafe_csv_course['tafe_filename']:
                        combined_obj = {**tafe_course, **training_course, **tafe_csv_course}
                        merged_courses.append(combined_obj)
    return merged_courses
                    
merged_courses = merge_three_datasets(tafe_csv_courses, training_courses, tafe_courses)

# %%
len(merged_courses)
# Out:
# 1329

# %% [markdown]
# # 11. Output merged data to JSON file

# %%
def output_to_json_file(obj, json_output_file, directory=os.getcwd()):
    """
    Saves an object (LIST/DIRECTORY) to a JSON file
    Returns Nothing
    """
    previous_directory = os.getcwd()
    os.chdir(directory)
    with open(json_output_file, 'w') as f:
        f.write(json.dumps(obj, indent=2, sort_keys=True))
    
    os.chdir(previous_directory)
    
output_to_json_file(merged_courses, JSON_OUTPUT_FILE, wd)

# %% [markdown]
# ### Some notes
# 46: CRS1400029 - Not on training.gov.au (searched on keywords and code)
# 1325: TAESS00009 - A skill set not a qual (thus no pertinent ASCED)
# 1326: UEESS00048 - A skill set not a qual (thus no pertinent ASCED)
# 1327: UEESS00051 - A skill set not a qual (thus no pertinent ASCED)
# 1328: UEESS00052 - A skill set not a qual (thus no pertinent ASCED)
# 1329: MEASS00443 - A skill set not a qual (thus no pertinent ASCED)
